# %%
import torch
import pandas as pd

# %%
torch.cuda.is_available()
# Out:
# True

# %%
df = pd.read_csv('/kaggle/input/ria-before-2025/RIA_before_2025.csv').dropna()
df
# Out:
#                        date  year  month  day  \
# 0       2020-01-01 00:32:53  2020      1    1
# 1       2020-01-01 00:54:16  2020      1    1
# 2       2020-01-01 12:44:25  2020      1    1
# 3       2020-01-01 12:55:30  2020      1    1
# 4       2020-01-01 15:20:14  2020      1    1
# ...                     ...   ...    ...  ...
# 186873  2024-12-31 18:21:42  2024     12   31
# 186874  2024-12-31 19:45:52  2024     12   31
# 186876  2024-12-31 21:02:19  2024     12   31
# 186877  2024-12-31 21:05:02  2024     12   31
# 186878  2024-12-31 22:57:52  2024     12   31
#
#                                                      text
# 0       Трамп вновь пригрозил последствиями Ирану, есл...
# 1       Ким Чен Ын пообещал скоро представить новое ст...
# 2       В России почти 6,5 миллиона человек встретили ...
# 3       Столкновения произошли в Гонконге во время сог...
# 4       Папа Римский Франциск извинился за то, что нак...
# ...                                                   ...
# 186873  Заявка на транзит российского газа через Украи...
# 186874  \n\n▪️Российские войска нанесли групповой удар...
# 186876  ❗️Путин заслушал доклады начальника Генштаба, ...
# 186877  Повторные выбросы нефтепродуктов зафиксированы...
# 186878  Нарушенное ракетным обстрелом ВСУ электроснабж...
#
# [168735 rows x 5 columns]

# %%
df.head(50)
# Out:
#     index                                               text
# 0       0  Трамп вновь пригрозил последствиями Ирану, есл...
# 1       1  Ким Чен Ын пообещал скоро представить новое ст...
# 2       2  В России почти 6,5 миллиона человек встретили ...
# 3       3  Столкновения произошли в Гонконге во время сог...
# 4       4  Папа Римский Франциск извинился за то, что нак...
# 5       5  Более 75,5 тысяч пассажиров встретили Новый го...
# 6       6  В России в ночь на 1 января , сообщает «Столот...
# 7       7  Украинские силовики заявили, что в новом году ...
# 8       8  Экс-глава Национальной баскетбольной ассоциаци...
# 9       9  МЧС хочет  из зон чрезвычайных ситуаций при со...
# 10     10  Молодежная сборная России по хоккею обыграла к...
# 11     11  ❗️Военный самолет Ан-12 разбился на западе Суд...
# 12     12  Формирующие правительство Испании социалисты с...
# 13     13  Греция, Израиль и Кипр подписали соглашение о ...
# 14     14  ❗️Ракеты взрываются у международного аэропорта...
# 15     15  Местное ТВ публикует видео с места ракетной ат...
# 16     16  Россия добыла по итогам 2019 года  560,2 млн т...
# 17     17  ⚡️Глава спецподразделения "Кудс" иранского Кор...
# 18     18  ❗️, в которых - по первым данным - погибли ира...
# 19     19  Местные СМИ публикуют фото с места , в одной и...
# 20     20  ❗️Замглавы иракского шиитского ополчения Абу М...
# 21     21  Иракские силовики взяли в кольцо "зеленую зону...
# 22     22  Американский предупреждает, что убийством "вто...
# 23     23  ⚡️гибель главы спецподразделения КСИР генерала...
# 24     24  Первый твит Трампа после убийства иранского ге...
# 25     25  \n\n- удар по Сулеймани нанесли по распоряжени...
# 26     26  Нефть после убийства американскими военными ир...
# 27     27  ❗️Вооруженные силы США приведены в повышенную ...
# 28     28  - генерал возглавлял спецподразделение "Кудс" ...
# 29     29  ❗️Верховный лидер Ирана пообещал США месть за ...
# 30     30  Спикер палаты представителей США Пелоси заявил...
# 31     31  Москва рассматривает убийство главы спецподраз...
# 32     32  Госдеп США призвал американцев немедленно поки...
# 33     33  Крупнейшие блоки в парламенте Ирака "Саирун" и...
# 34     34  МИД РФ о возможности созыва СБ ООН после убийс...
# 35     35  Власти Ирана заявили, что ответят США на убийс...
# 36     36  Верховный лидер Ирана назначил бригадного гене...
# 37     37  Представитель главнокомандующего ВС Ирака заяв...
# 38     38  Помпео заявил что США готовы к возможному отве...
# 39     39  Недальновидные шаги США, выразившиеся в убийст...
# 40     40  Трамп заявил, что уничтоженный США иранский ге...
# 41     41  Путин и Макрон в ходе телефонного разговора вы...
# 42     42  Высший совет национальной безопасности Ирана п...
# 43     43  Глава МИД РФ Сергей Лавров и госсекретарь США ...
# 44     44  США отправят дополнительно 3000 военнослужащих...
# 45     45  Глава МИД Ирана в разговоре с генсеком ООН наз...
# 46     46  Трамп заявил, что Сулеймани надо было давно ли...
# 47     47  Авиаудар нанесен по автоколонне шиитского опол...
# 48     48  Армия Ирака отрицает факт авиаудара в районе э...
# 49     49  Российское правительство планирует в 2020 году...

# %%
import pandas as pd
import os  # Добавляем модуль os

# Загрузка данных (если они еще не загружены)
df = pd.read_csv('data/RIA_before_2025.csv').dropna().reset_index(drop=True).reset_index()[['index', 'text']]
df.to_csv('to_gemini.csv', index=False)  # Эта строка уже была, но я добавил её для полноты

# Определение размера чанка
chunk_size = 3000

# Общее количество строк
total_rows = len(df)

# Вычисление количества файлов (с округлением вверх)
num_files = (total_rows + chunk_size - 1) // chunk_size

# Создание папки для сохранения файлов
output_folder = 'gemini_chunks'  # Имя папки
if not os.path.exists(output_folder):  # Проверяем, существует ли папка
    os.makedirs(output_folder)  # Создаем папку, если она не существует


for i in range(num_files):
    # Вычисление начального и конечного индекса для текущего чанка
    start_index = i * chunk_size
    end_index = min((i + 1) * chunk_size, total_rows)  # min нужен, чтобы не выйти за пределы

    # Создание DataFrame для текущего чанка
    chunk_df = df.iloc[start_index:end_index]

    # Сохранение в файл
    filename = f'to_gemini_part_{i+1}.csv'  # Нумерация с 1
    filepath = os.path.join(output_folder, filename) # Полный путь к файлу, включая папку
    chunk_df.to_csv(filepath, index=False)

    print(f"Создан файл: {filename} (строки с {start_index} по {end_index -1})")

print("Разбиение завершено.")
# Out:
# Создан файл: to_gemini_part_1.csv (строки с 0 по 2999)
# Создан файл: to_gemini_part_2.csv (строки с 3000 по 5999)
# Создан файл: to_gemini_part_3.csv (строки с 6000 по 8999)
# Создан файл: to_gemini_part_4.csv (строки с 9000 по 11999)
# Создан файл: to_gemini_part_5.csv (строки с 12000 по 14999)
# Создан файл: to_gemini_part_6.csv (строки с 15000 по 17999)
# Создан файл: to_gemini_part_7.csv (строки с 18000 по 20999)
# Создан файл: to_gemini_part_8.csv (строки с 21000 по 23999)
# Создан файл: to_gemini_part_9.csv (строки с 24000 по 26999)
# Создан файл: to_gemini_part_10.csv (строки с 27000 по 29999)
# Создан файл: to_gemini_part_11.csv (строки с 30000 по 32999)
# Создан файл: to_gemini_part_12.csv (строки с 33000 по 35999)
# Создан файл: to_gemini_part_13.csv (строки с 36000 по 38999)
# Создан файл: to_gemini_part_14.csv (строки с 39000 по 41999)
# Создан файл: to_gemini_part_15.csv (строки с 42000 по 44999)
# Создан файл: to_gemini_part_16.csv (строки с 45000 по 47999)
# Создан файл: to_gemini_part_17.csv (строки с 48000 по 50999)
# Создан файл: to_gemini_part_18.csv (строки с 51000 по 53999)
# Создан файл: to_gemini_part_19.csv (строки с 54000 по 56999)
# Создан файл: to_gemini_part_20.csv (строки с 57000 по 59999)
# Создан файл: to_gemini_part_21.csv (строки с 60000 по 62999)
# Создан файл: to_gemini_part_22.csv (строки с 63000 по 65999)
# Создан файл: to_gemini_part_23.csv (строки с 66000 по 68999)
# Создан файл: to_gemini_part_24.csv (строки с 69000 по 71999)
# Создан файл: to_gemini_part_25.csv (строки с 72000 по 74999)
# Создан файл: to_gemini_part_26.csv (строки с 75000 по 77999)
# Создан файл: to_gemini_part_27.csv (строки с 78000 по 80999)
# Создан файл: to_gemini_part_28.csv (строки с 81000 по 83999)
# Создан файл: to_gemini_part_29.csv (строки с 84000 по 86999)
# Создан файл: to_gemini_part_30.csv (строки с 87000 по 89999)
# Создан файл: to_gemini_part_31.csv (строки с 90000 по 92999)
# Создан файл: to_gemini_part_32.csv (строки с 93000 по 95999)
# Создан файл: to_gemini_part_33.csv (строки с 96000 по 98999)
# Создан файл: to_gemini_part_34.csv (строки с 99000 по 101999)
# Создан файл: to_gemini_part_35.csv (строки с 102000 по 104999)
# Создан файл: to_gemini_part_36.csv (строки с 105000 по 107999)
# Создан файл: to_gemini_part_37.csv (строки с 108000 по 110999)
# Создан файл: to_gemini_part_38.csv (строки с 111000 по 113999)
# Создан файл: to_gemini_part_39.csv (строки с 114000 по 116999)
# Создан файл: to_gemini_part_40.csv (строки с 117000 по 119999)
# Создан файл: to_gemini_part_41.csv (строки с 120000 по 122999)
# Создан файл: to_gemini_part_42.csv (строки с 123000 по 125999)
# Создан файл: to_gemini_part_43.csv (строки с 126000 по 128999)
# Создан файл: to_gemini_part_44.csv (строки с 129000 по 131999)
# Создан файл: to_gemini_part_45.csv (строки с 132000 по 134999)
# Создан файл: to_gemini_part_46.csv (строки с 135000 по 137999)
# Создан файл: to_gemini_part_47.csv (строки с 138000 по 140999)
# Создан файл: to_gemini_part_48.csv (строки с 141000 по 143999)
# Создан файл: to_gemini_part_49.csv (строки с 144000 по 146999)
# Создан файл: to_gemini_part_50.csv (строки с 147000 по 149999)
# Создан файл: to_gemini_part_51.csv (строки с 150000 по 152999)
# Создан файл: to_gemini_part_52.csv (строки с 153000 по 155999)
# Создан файл: to_gemini_part_53.csv (строки с 156000 по 158999)
# Создан файл: to_gemini_part_54.csv (строки с 159000 по 161999)
# Создан файл: to_gemini_part_55.csv (строки с 162000 по 164999)
# Создан файл: to_gemini_part_56.csv (строки с 165000 по 167999)
# Создан файл: to_gemini_part_57.csv (строки с 168000 по 168734)
# Разбиение завершено.

# %% [markdown]
# Ты — редактор новостного агрегатора в России. Твоя задача: категоризировать новости ('news') для российских читателей, создав две колонки: 'multi _labels и
# *hier label'. Учитывай, что эти данные будут использоваться моделью Longformer для мультиклассовой классификации, поэтому *количество уникальных классов должно быть ограничено*.
# 1. ***multi labels ** Перечисли *наиболее значимые* категории новости через точку с запятой (;), в порядке убывания вероятности. Используй
# *ограниченный набор* категорий (не более 5-7). Выбирай наиболее общие и репрезентативные категории, которые охватывают основные темы новости.
# Избегай слишком узких или специфичных категорий.
# * **Примеры категорий:** Политика, Экономика, Общество, Происшествия, Спорт, Культура, Технологии, Международные отношения, Региональные новости. (Можно добавить/изменить список, но он должен быть конечным и не слишком большим).
# * **Плохой пример:** "Политика; Экономика; Внутренняя политика; Законодательство; Налоги; Пенсионная реформа" (слишком много и слишком подробно)
# * **Хороший пример:** "Политика; Экономика; Общество"
# 2. **'hier label :** Для *первой* категории из multi labels создай двухуровневую иерархию (уровень!/уровень2). Уровень2 должен *уточнять* Уровень! и быть
# *более конкретным*, чем любая категория из 'multi _labels*, но *оставаться в рамках разумного количества уникальных значений*. Используй ограниченный набор уточнений для второго уровня.
# * **Плохой пример:** "Политика/Встреча президента Иванова с премьер-министром Петровым 23 мая 2024 года в Кремле" (слишком специфично)
# * **Хороший пример:** "Политика/Внутренняя политика"
# * **Хороший пример:** "Происшествия/ДТП"
# 3. **Контекст:** Анализируй с точки зрения российского гражданина, объективно, но учитывая российские реалии.
# Добавь только колонки 'multi labels' и 'hier label' к исходной news'.

# %%
labels_df = pd.read_json('result.json')
labels_df
# Out:
#      index                                       multi_labels  \
# 0        0  [Международные отношения, Политика, Происшествия]
# 1        1    [Международные отношения, Политика, Вооружение]
# 2        2         [Общество, Региональные новости, Политика]
# 3        3  [Международные отношения, Происшествия, Политика]
# 4        4       [Международные отношения, Религия, Общество]
# ..     ...                                                ...
# 108    108                [Международные отношения, Политика]
# 109    109     [Международные отношения, Экономика, Политика]
# 110    110                [Политика, Международные отношения]
# 111    111                [Политика, Международные отношения]
# 112    112                [Международные отношения, Политика]
#
#                                hier_label
# 0    [Международные отношения, Конфликты]
# 1     [Международные отношения, Политика]
# 2                   [Общество, Праздники]
# 3     [Международные отношения, Протесты]
# 4      [Международные отношения, Религия]
# ..                                    ...
# 108   [Международные отношения, Политика]
# 109  [Международные отношения, Экономика]
# 110       [Политика, Внутренняя политика]
# 111       [Политика, Внутренняя политика]
# 112   [Международные отношения, Политика]
#
# [113 rows x 3 columns]

# %%
df = pd.read_csv('data/RIA_before_2025.csv').dropna().reset_index(drop=True).reset_index()
df
# Out:
#          index                 date  year  month  day  \
# 0            0  2020-01-01 00:32:53  2020      1    1
# 1            1  2020-01-01 00:54:16  2020      1    1
# 2            2  2020-01-01 12:44:25  2020      1    1
# 3            3  2020-01-01 12:55:30  2020      1    1
# 4            4  2020-01-01 15:20:14  2020      1    1
# ...        ...                  ...   ...    ...  ...
# 168730  168730  2024-12-31 18:21:42  2024     12   31
# 168731  168731  2024-12-31 19:45:52  2024     12   31
# 168732  168732  2024-12-31 21:02:19  2024     12   31
# 168733  168733  2024-12-31 21:05:02  2024     12   31
# 168734  168734  2024-12-31 22:57:52  2024     12   31
#
#                                                      text
# 0       Трамп вновь пригрозил последствиями Ирану, есл...
# 1       Ким Чен Ын пообещал скоро представить новое ст...
# 2       В России почти 6,5 миллиона человек встретили ...
# 3       Столкновения произошли в Гонконге во время сог...
# 4       Папа Римский Франциск извинился за то, что нак...
# ...                                                   ...
# 168730  Заявка на транзит российского газа через Украи...
# 168731  \n\n▪️Российские войска нанесли групповой удар...
# 168732  ❗️Путин заслушал доклады начальника Генштаба, ...
# 168733  Повторные выбросы нефтепродуктов зафиксированы...
# 168734  Нарушенное ракетным обстрелом ВСУ электроснабж...
#
# [168735 rows x 6 columns]

# %%
merged_df = pd.merge(df, labels_df, on='index')
merged_df
# Out:
#      index                 date  year  month  day  \
# 0        0  2020-01-01 00:32:53  2020      1    1
# 1        1  2020-01-01 00:54:16  2020      1    1
# 2        2  2020-01-01 12:44:25  2020      1    1
# 3        3  2020-01-01 12:55:30  2020      1    1
# 4        4  2020-01-01 15:20:14  2020      1    1
# ..     ...                  ...   ...    ...  ...
# 108    108  2020-01-07 16:53:05  2020      1    7
# 109    109  2020-01-07 20:59:00  2020      1    7
# 110    110  2020-01-07 21:37:13  2020      1    7
# 111    111  2020-01-07 22:10:39  2020      1    7
# 112    112  2020-01-07 22:58:09  2020      1    7
#
#                                                   text  \
# 0    Трамп вновь пригрозил последствиями Ирану, есл...
# 1    Ким Чен Ын пообещал скоро представить новое ст...
# 2    В России почти 6,5 миллиона человек встретили ...
# 3    Столкновения произошли в Гонконге во время сог...
# 4    Папа Римский Франциск извинился за то, что нак...
# ..                                                 ...
# 108  ❗️Путин прибыл с визитом в Дамаск, сообщил пре...
# 109  Путин во вторник вечером прибыл в Турцию, где ...
# 110  Утверждение социалиста  на пост премьера  .\n\...
# 111  Утро вторника в Венесуэле было насыщенным. Пар...
# 112  Трамп: когда-нибудь США уйдут из Ирака, но не ...
#
#                                           multi_labels  \
# 0    [Международные отношения, Политика, Происшествия]
# 1      [Международные отношения, Политика, Вооружение]
# 2           [Общество, Региональные новости, Политика]
# 3    [Международные отношения, Происшествия, Политика]
# 4         [Международные отношения, Религия, Общество]
# ..                                                 ...
# 108                [Международные отношения, Политика]
# 109     [Международные отношения, Экономика, Политика]
# 110                [Политика, Международные отношения]
# 111                [Политика, Международные отношения]
# 112                [Международные отношения, Политика]
#
#                                hier_label
# 0    [Международные отношения, Конфликты]
# 1     [Международные отношения, Политика]
# 2                   [Общество, Праздники]
# 3     [Международные отношения, Протесты]
# 4      [Международные отношения, Религия]
# ..                                    ...
# 108   [Международные отношения, Политика]
# 109  [Международные отношения, Экономика]
# 110       [Политика, Внутренняя политика]
# 111       [Политика, Внутренняя политика]
# 112   [Международные отношения, Политика]
#
# [113 rows x 8 columns]

# %%
merged_df.to_csv('merged_df.csv', index=False)
